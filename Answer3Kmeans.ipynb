# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN
from sklearn.decomposition import PCA

# %%
train=np.genfromtxt('holiday.data',delimiter=',')

# %%
train=train[1:]

# %%
wcss=[]
for i in range(1,5):
    cl=KMeans(n_clusters=i,max_iter=100)
    cl.fit(train)
    wcss.append(cl.inertia_)


plt.plot(range(1,5),wcss)

# %%
K_best=4
pc=np.genfromtxt('holiday.test',delimiter=',')
pc=pc[1:]

# %%
cl1=KMeans(n_clusters=4)
cl1.fit(pc)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
a=cl1.predict(pc)

# %%
plt.scatter(train[a==0,0],train[a==0,1],c='red')
plt.scatter(train[a==1,0],train[a==1,1],c='blue')
plt.scatter(train[a==2,0],train[a==2,1],c='purple')
plt.scatter(train[a==3,0],train[a==3,1],c='Green')
